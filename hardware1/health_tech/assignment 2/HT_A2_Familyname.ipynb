# %% [markdown]
# # Assignment 2. Heart rate detection
# Hardware 1 - Orientation to Health Technology<br>
# Your name: **Janne Savinainen**<br>
# Date returned: **The date returned comes here**<br>
# Metropolia University of Applied Sciences<br>

# %% [markdown]
# ## 1. Setup

# %%
import numpy as np
import matplotlib.pyplot as plt
import heartpy as hp

# %% [markdown]
# ## 2. All data
# Read in and plot all data.

# %%
# Reads the file into a numpy array
data = hp.get_data('capture01_250Hz.txt')
# Create a time vector
Fs = 250 # Sampling rate (samples per second)
time = np.arange(len(data))/Fs

# Plot the whole data in a graphical figure
plt.figure(figsize = (12, 4))
plt.plot(time, data)
plt.grid()
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (uint16)')
plt.show()

# %% [markdown]
# ## 3. Selected segment
# Select a **60 seconds** segment from the data and make a graph of it.

# %%
# Random seed based on the last four digits of the student ID number
np.random.seed(2626)
t0 = np.random.randint(30, 100)
print(f'Segment starts from: {t0} s')

# Select a segment
i = (t0 < time) & (time < t0 + 60)
data2 = data[i]
time2 = time[i]

# Plot the selected segment
plt.figure(figsize = (12, 4))
plt.plot(time2, data2)
plt.grid()
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (uint16)')
plt.show()
# Out:
# Segment starts from: 48 s

# %% [markdown]
# ## 4. Peak detection and HRV measurements
# Detect the peaks from the selected segment of data, make a graph of the processed data segment to show the peaks, and finally display the measures computed.

# %%
# Zoom in to the first 6 seconds to show the details of the signal

# Plot the selected segment
plt.figure(figsize = (12, 4))
plt.plot(time2, data2)
plt.grid()
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (uint16)')
plt.xlim(t0, t0 + 6)
plt.show()

# %%
wd, m = hp.process(data2, sample_rate = 250.0)

#set large figure
plt.figure(figsize=(12,4))

#call plotter
hp.plotter(wd, m)

#display measures computed
for measure in m.keys():
    print('%s: %f' %(measure, m[measure]))
# Out:
# bpm: 66.269496
# ibi: 905.393939
# sdnn: 26.719576
# sdsd: 8.949563
# rmssd: 13.767297
# pnn20: 0.169231
# pnn50: 0.000000
# hr_mad: 24.000000
# sd1: 9.728723
# sd2: 36.666545
# s: 1120.664690
# sd1/sd2: 0.265330
# breathingrate: 0.233333

# %% [markdown]
# ## 5. Interpretations
# Interpret the results.

# %% [markdown]
# **(DOUBLE CLICK AND)** Write your interpretations of the results here ...
#
# 1. Average heart rade was was 66.27 beat per minute (bpm). 66.27 bpm is normal for 55 years old man.
# 2. The average inter-beat-interval is 905.39 milliseconds. IBI is normal for 55 years old man.
# 3. SDNN measures the overall variability of the inter-beat-intervals. The measured SDNN is 26.72 ms
# 4. The person's heart rate seems to be within a normal range, indicating a relaxed or resting state.
